# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <strong>Milos Banduka</strong>
# <hr>
# Software Engineer

# %% [markdown]
# <em>I am interested in data science because I'm passionate about the Data and I consider myself as a data-driven person</em>

# %% [markdown]
# <h3>Code below will take the input and print it back to you</h3>

# %%
inp = input('What is your name')
print('Hello, {} nice to meet you'.format(inp))
# Out:
# What is your name Hello
# Hello, Hello nice to meet you

# %% [markdown]
# ### Explanation
# ___
# Code above is basic python I/O example, it's pretty simple.
# 1. declare input variable for input prompt
# 2. print out the value concatenating the string typed by the user and static string.
#
# Code Example
# ```
# inp = input('What is your name')
# print('Hello, {} nice to meet you'.format(inp))
# ```
